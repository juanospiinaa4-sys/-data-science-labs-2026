# %%
print("Hello, Data Science! My name is Juan")
# Out:
# Hello, Data Science! My name is Juan

# %%
import sys
print("Python version:", sys.version)
# Out:
# Python version: 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
